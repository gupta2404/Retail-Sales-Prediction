# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Downloads\Rossmann Stores Data (1).csv")

# %%
df2=pd.read_csv(r"C:\Users\LENOVO\Downloads\store (1).csv")

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.tail()
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1

# %%
df.shape
# Out:
# (1017209, 9)

# %%
df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().any()
# Out:
# Store            False
# DayOfWeek        False
# Date             False
# Sales            False
# Customers        False
# Open             False
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %% [markdown]
# There are no missing values in the dataset

# %%
round(df.describe(),2)
# Out:
#             Store  DayOfWeek       Sales   Customers        Open       Promo  \
# count  1017209.00  1017209.0  1017209.00  1017209.00  1017209.00  1017209.00
# mean       558.43        4.0     5773.82      633.15        0.83        0.38
# std        321.91        2.0     3849.93      464.41        0.38        0.49
# min          1.00        1.0        0.00        0.00        0.00        0.00
# 25%        280.00        2.0     3727.00      405.00        1.00        0.00
# 50%        558.00        4.0     5744.00      609.00        1.00        0.00
# 75%        838.00        6.0     7856.00      837.00        1.00        1.00
# max       1115.00        7.0    41551.00     7388.00        1.00        1.00
#
#        SchoolHoliday
# count     1017209.00
# mean            0.18
# std             0.38
# min             0.00
# 25%             0.00
# 50%             0.00
# 75%             0.00
# max             1.00

# %%
df2
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
df2.shape
# Out:
# (1115, 10)

# %%
df2.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
df2['CompetitionDistance'].fillna(df2['CompetitionDistance'].median(),inplace=True)

# %%
df2['CompetitionOpenSinceMonth'].fillna(0,inplace=True)

# %%
df2['CompetitionOpenSinceYear'].fillna(0,inplace=True)

# %%
df2['Promo2SinceWeek'].fillna(0,inplace=True)

# %%
df2['Promo2SinceYear'].fillna(0,inplace=True)

# %%
df2['PromoInterval'].fillna(0,inplace=True)

# %%
df2.isnull().any()
# Out:
# Store                        False
# StoreType                    False
# Assortment                   False
# CompetitionDistance          False
# CompetitionOpenSinceMonth    False
# CompetitionOpenSinceYear     False
# Promo2                       False
# Promo2SinceWeek              False
# Promo2SinceYear              False
# PromoInterval                False
# dtype: bool

# %%
li1=list(df2.select_dtypes('float64'))
li1
# Out:
# ['CompetitionDistance',
#  'CompetitionOpenSinceMonth',
#  'CompetitionOpenSinceYear',
#  'Promo2SinceWeek',
#  'Promo2SinceYear']

# %%
for col in li1:
    df2[col]=df2[col].astype('int')

# %%
data=pd.merge(df,df2)

# %%
data
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
data.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
for i in data.columns:
    print(data[[i]].nunique())
# Out:
# Store    1115
# dtype: int64
# DayOfWeek    7
# dtype: int64
# Date    942
# dtype: int64
# Sales    21734
# dtype: int64
# Customers    4086
# dtype: int64
# Open    2
# dtype: int64
# Promo    2
# dtype: int64
# StateHoliday    5
# dtype: int64
# SchoolHoliday    2
# dtype: int64
# StoreType    4
# dtype: int64
# Assortment    3
# dtype: int64
# CompetitionDistance    655
# dtype: int64
# CompetitionOpenSinceMonth    13
# dtype: int64
# CompetitionOpenSinceYear    24
# dtype: int64
# Promo2    2
# dtype: int64
# Promo2SinceWeek    25
# dtype: int64
# Promo2SinceYear    8
# dtype: int64
# PromoInterval    4
# dtype: int64

# %%
round(data.describe(),2)
# Out:
#             Store  DayOfWeek       Sales   Customers        Open       Promo  \
# count  1017209.00  1017209.0  1017209.00  1017209.00  1017209.00  1017209.00
# mean       558.43        4.0     5773.82      633.15        0.83        0.38
# std        321.91        2.0     3849.93      464.41        0.38        0.49
# min          1.00        1.0        0.00        0.00        0.00        0.00
# 25%        280.00        2.0     3727.00      405.00        1.00        0.00
# 50%        558.00        4.0     5744.00      609.00        1.00        0.00
# 75%        838.00        6.0     7856.00      837.00        1.00        1.00
# max       1115.00        7.0    41551.00     7388.00        1.00        1.00
#
#        SchoolHoliday  CompetitionDistance  CompetitionOpenSinceMonth  \
# count     1017209.00           1017209.00                 1017209.00
# mean            0.18              5422.02                       4.93
# ...

# %%
store_with_top_sales=data.groupby('Store')['Sales'].mean().sort_values(ascending=False).head(10)
store_with_top_sales
# Out:
# Store
# 262     20718.515924
# 817     18108.139066
# 562     17969.556263
# 1114    17200.196391
# 251     15814.087049
# 842     15242.114776
# 513     15129.942675
# 788     14949.194268
# 733     14933.288747
# 383     14320.466030
# Name: Sales, dtype: float64

# %%
store_with_least_sale=data.groupby('Store')['Sales'].mean().sort_values().head(10)
store_with_least_sale
# Out:
# Store
# 307    2244.503185
# 543    2313.468153
# 198    2407.933121
# 208    2443.791932
# 841    2461.395966
# 254    2485.839703
# 972    2550.559448
# 794    2553.475584
# 219    2591.467091
# 210    2641.309979
# Name: Sales, dtype: float64

# %% [markdown]
# Store 262 has highest average sales.

# %%
data.groupby('DayOfWeek')['Customers'].count().sort_values()
# Out:
# DayOfWeek
# 1    144730
# 6    144730
# 7    144730
# 2    145664
# 3    145665
# 4    145845
# 5    145845
# Name: Customers, dtype: int64

# %%
data.groupby('DayOfWeek')['Sales'].mean()
# Out:
# DayOfWeek
# 1    7809.044510
# 2    7005.244467
# 3    6555.884138
# 4    6247.575913
# 5    6723.274305
# 6    5847.562599
# 7     204.183189
# Name: Sales, dtype: float64

# %%
new_data=pd.get_dummies(data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  datetime64[ns]
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1017209 non-null  int32
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.displot(data=data,x='Sales',bins=40,kde=True)
plt.show()

# %%
store_with_top_sales.plot(kind='bar',color='purple')
# Out:
# <Axes: xlabel='Store'>

# %%
store_with_least_sale.plot(kind='bar',color='orange')
# Out:
# <Axes: xlabel='Store'>

# %%
plt.figure(figsize=(6,3))
sns.lineplot(data=data,x='DayOfWeek',y='Sales',color='green')
plt.title('Day VS Sales graph')
plt.show()

# %%
sns.barplot(data=data,x='DayOfWeek',y='Customers')
# Out:
# <Axes: xlabel='DayOfWeek', ylabel='Customers'>

# %%
for i in range(1,8):
    print('day of week is ',i)
    print(data[data[['DayOfWeek','Open']]['DayOfWeek']==i][['DayOfWeek','Open']]['Open'].value_counts())
# Out:
# day of week is  1
# 1    137560
# 0      7170
# Name: Open, dtype: int64
# day of week is  2
# 1    143961
# 0      1703
# Name: Open, dtype: int64
# day of week is  3
# 1    141936
# 0      3729
# Name: Open, dtype: int64
# day of week is  4
# 1    134644
# 0     11201
# Name: Open, dtype: int64
# day of week is  5
# 1    138640
# 0      7205
# Name: Open, dtype: int64
# day of week is  6
# 1    144058
# 0       672
# Name: Open, dtype: int64
# day of week is  7
# 0    141137
# 1      3593
# Name: Open, dtype: int64

# %%
plt.bar(data['DayOfWeek'],)

# %%
sns.barplot(data=data,x='DayOfWeek',y='Open')
# Out:
# <Axes: xlabel='DayOfWeek', ylabel='Open'>

# %%
data.groupby(['DayOfWeek','Open']).count()
# Out:
#                  Store    Date   Sales  Customers   Promo  StateHoliday  \
# DayOfWeek Open
# 1         0       7170    7170    7170       7170    7170          7170
#           1     137560  137560  137560     137560  137560        137560
# 2         0       1703    1703    1703       1703    1703          1703
#           1     143961  143961  143961     143961  143961        143961
# 3         0       3729    3729    3729       3729    3729          3729
#           1     141936  141936  141936     141936  141936        141936
# 4         0      11201   11201   11201      11201   11201         11201
#           1     134644  134644  134644     134644  134644        134644
# 5         0       7205    7205    7205       7205    7205          7205
#           1     138640  138640  138640     138640  138640        138640
# 6         0        672     672     672        672     672           672
#           1     144058  144058  144058     144058  144058        144058
# ...

# %%
data['Open'].value_counts(normalize=True)
# Out:
# 1    0.830107
# 0    0.169893
# Name: Open, dtype: float64

# %%
sns.barplot(data=data,x='Promo',y='Sales')
# Out:
# <Axes: xlabel='Promo', ylabel='Sales'>

# %%
sns.barplot(data=data,x='StateHoliday',y='Sales')
# Out:
# <Axes: xlabel='StateHoliday', ylabel='Sales'>

# %%
sns.barplot(data=df,x='SchoolHoliday',y='Sales')
# Out:
# <Axes: xlabel='SchoolHoliday', ylabel='Sales'>

# %%
plt.figure(figsize=(6,4))
sns.pointplot(data=data,x='CompetitionOpenSinceMonth',y='Sales')
plt.xlim([0,12])
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.pointplot(data=data,x='CompetitionOpenSinceYear',y='Sales',color='red')
plt.title('Sales w.r.t number of competitor')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.violinplot(data=data,x='StoreType',y='Sales')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.violinplot(data=data,x='Assortment',y='Sales')
plt.show()

# %%
sns.lineplot(data=data,x='CompetitionDistance',y='Sales')
# Out:
# <Axes: xlabel='CompetitionDistance', ylabel='Sales'>

# %%
sns.barplot(data=data,x='Promo2',y='Sales')
# Out:
# <Axes: xlabel='Promo2', ylabel='Sales'>

# %%
sns.pointplot(data=data,x='Promo2SinceYear',y='Sales')
# Out:
# <Axes: xlabel='Promo2SinceYear', ylabel='Sales'>

# %%
sns.violinplot(data=data,x='PromoInterval',y='Sales')
# Out:
# <Axes: xlabel='PromoInterval', ylabel='Sales'>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data)
plt.show()

# %%
data.corr()
# Out:
#                               Store  DayOfWeek     Sales  Customers      Open  \
# Store                      1.000000  -0.000008  0.005126   0.024325 -0.000047
# DayOfWeek                 -0.000008   1.000000 -0.462125  -0.386445 -0.528963
# Sales                      0.005126  -0.462125  1.000000   0.894711  0.678472
# Customers                  0.024325  -0.386445  0.894711   1.000000  0.616768
# Open                      -0.000047  -0.528963  0.678472   0.616768  1.000000
# Promo                      0.000058  -0.392925  0.452345   0.316169  0.295042
# SchoolHoliday              0.000641  -0.205388  0.085124   0.071568  0.086171
# CompetitionDistance       -0.026451  -0.000025 -0.018869  -0.102362  0.007987
# CompetitionOpenSinceMonth -0.032893   0.000008 -0.012431  -0.015188 -0.000200
# CompetitionOpenSinceYear  -0.008794   0.000007  0.002749   0.000489 -0.001144
# Promo2                     0.008488   0.000168 -0.091040  -0.150159 -0.008309
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),annot=True,cmap='BuPu',linewidth=0.1)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  datetime64[ns]
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1017209 non-null  int32
# ...

# %% [markdown]
# # One Hot Encoding

# %%
dummy_data=pd.get_dummies(data,drop_first=True)
dummy_data
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#          SchoolHoliday  CompetitionDistance  CompetitionOpenSinceMonth  ...  \
# ...

# %% [markdown]
# # Applying Lnear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
x=dummy_data.drop(['Sales','Date'],axis=1)
y=dummy_data['Sales']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
dummy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Store                           1017209 non-null  int64
#  1   DayOfWeek                       1017209 non-null  int64
#  2   Date                            1017209 non-null  datetime64[ns]
#  3   Sales                           1017209 non-null  int64
#  4   Customers                       1017209 non-null  int64
#  5   Open                            1017209 non-null  int64
#  6   Promo                           1017209 non-null  int64
#  7   SchoolHoliday                   1017209 non-null  int64
#  8   CompetitionDistance             1017209 non-null  int32
#  9   CompetitionOpenSinceMonth       1017209 non-null  int32
#  10  CompetitionOpenSinceYear        1017209 non-null  int32
# ...

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-8.48306227e-02, -4.90460682e+01,  7.26337197e+00,  8.40795508e+02,
#         1.11813428e+03,  5.79365750e+01,  2.03107975e-02, -4.34633149e+00,
#         5.58239048e-02,  6.73248976e+04,  5.92743346e+00, -4.45872083e+01,
#         1.49570310e+02, -4.56317071e+02, -6.69678812e+02, -2.82717901e+01,
#        -3.10884054e+03, -1.10910868e+02,  9.15699758e+02, -4.04028758e+03,
#         2.94458552e+02,  2.24610377e+04,  2.25188695e+04,  2.23449904e+04])

# %%
reg.intercept_
# Out:
# -433.6041697687533

# %%
reg.score(x_train,y_train)
# Out:
# 0.9001893394093332

# %%
reg.score(x_test,y_test)
# Out:
# 0.8996564993385335

# %%
np.array(y_test)
# Out:
# array([3598, 7212, 5894, ..., 6184, 3335, 5922], dtype=int64)

# %%
reg.predict(x_test)
# Out:
# array([3931.0857616 , 6719.2420575 , 5993.19235904, ..., 7296.08624578,
#        3835.53041956, 5256.03412511])
